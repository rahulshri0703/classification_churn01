# %%
from churn_model import pipeline
from churn_model import config
from churn_model.processing.validation import validate_inputs
from churn_model.processing.load_data import load_pipeline,load_dataset

# %%
x_train = load_dataset(filename=config.app_config.x_train)
pipeline = load_pipeline(filename=config.app_config.final_pipeline)

# %%
pipeline[:-1]
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('dropAndRename',
#                                   dropAndRenameColumns(categorical=['monthly_3g_6',
#                                                                     'monthly_2g_7',
#                                                                     'monthly_2g_8',
#                                                                     'sachet_2g_6',
#                                                                     'sachet_3g_7',
#                                                                     'monthly_3g_8',
#                                                                     'monthly_2g_6',
#                                                                     'sachet_3g_8',
#                                                                     'sachet_3g_6',
#                                                                     'monthly_3g_7',
# ...

# %%
from churn_model.predict import make_prediction
from churn_model import config
from churn_model.processing.load_data import load_dataset
import pytest

x = load_dataset(filename=config.app_config.x_train).head(5)

# %%
input1 = x.copy()
input2 = x.to_dict(orient='records')
input3 = x.head(1).to_dict(orient='records')

# %%
results = make_prediction(input_data=input3)
results
# Out:
# {'predictions': [0], 'version': '0.0.1', 'errors': None}

# %%
from churn_model import config
from churn_model.processing.load_data import load_dataset
from churn_model.processing.validation import validate_inputs

# %%
x = load_dataset(filename=config.app_config.x_train).head(15)

# %%
xx,e = validate_inputs(input_data=x)

# %%
e

# %%
xx
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7002222687        109             0.0             0.0             0.0
# 1     7001544619        109             0.0             0.0             0.0
# 2     7000094324        109             0.0             0.0             0.0
# 3     7001333859        109             0.0             0.0             0.0
# 4     7002074678        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8   arpu_6  \
# 0            6/30/2014            7/31/2014            8/31/2014  710.657
# 1            6/30/2014            7/31/2014            8/31/2014  837.086
# 2            6/30/2014            7/31/2014            8/31/2014  752.352
# 3            6/30/2014            7/31/2014            8/31/2014  384.124
# 4            6/30/2014            7/31/2014            8/31/2014  695.997
#
# ...

# %%
def test_predict_valid_input():

   

    train = load_dataset(filename=config.app_config.x_train).head(5)

    v, error = validate_inputs(input_data=train)
    

    
    assert error is None

# %%
test_predict_valid_input()

# %%
x = load_dataset(filename=config.app_config.x_train).head(5)

input1 = x.copy()
input2 = x.to_dict(orient='records')
input3 = x.head(1).to_dict(orient='records')

# %%
from churn_model.predict import make_prediction

results = make_prediction(input_data=input2)

# %%
assert isinstance(results['predictions'],list)==True
